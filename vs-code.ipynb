# %% [markdown]
# # VS Code Setup
#
# ```bash
# git init
#
# nano .gitignore
#
# git add .
#
# git commit -m "initial message"
#
# git branch -m main
#
# git remote add origin git@github-personal:devkumar70401/Notes.git
#
# git remote -v
#
# git push -u origin main
# ```
#
# If git commit fails
#
# ```bash
# git config user.name "devkumar70401"
# git congig user.email "devkumar70401@gmail.com"
# ```
# then try again to commit
#
# In case push failed
#
# then
#
# ```bash
#
# git push -u origin main -- force (if online repo content is not imp*)
#
# ```

# %% [markdown]
# # Setting up SSH
#
# ```bash
# cat ~/.ssh/config
# ```
